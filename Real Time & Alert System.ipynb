# %% [markdown]
# # <a name="0">State Farm Distracted Driver Detection in Real Time & Alert System</a>

# %% [markdown]
# ## <div style="background-color:#015958;font-family:sans-serif;color:#FFF9ED;font-size:150%;text-align:center;border-radius:9px 9px; padding: 15px; border-style: solid; border-color: black"> Real Time </div>

# %%
import cv2
from ultralytics import YOLO

# Load the pre-trained YOLOv8 classification model
model = YOLO(r"D:\Personal\5. Courses\Depi\Technical\Runs\Classify\Train\weights\best.pt")  # Replace with your custom trained model

# Capture video from the dashboard camera (or default camera)
cap = cv2.VideoCapture(0)  # '0' is for the default camera, adjust if necessary

# Set the frame width and height if necessary (optional)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)

# Define the class names based on your dataset (adjust as needed for your custom model)
class_names = [
    "safe driving", "texting - right", "talking on the phone - right",
    "texting - left", "talking on the phone - left", "operating the radio",
    "drinking", "reaching behind", "hair and makeup", "talking to passenger"
]

while True:
    # Read a frame from the camera
    ret, frame = cap.read()
    if not ret:
        print("Failed to capture video")
        break

    # Preprocess: Resize the frame to match YOLOv8 input size for classification
    input_frame = cv2.resize(frame, (224, 224))  # Resize to the input size required by your model

    # YOLOv8 classification inference on the frame (get predictions)
    results = model(input_frame)

    # YOLOv8 returns a list of results, so access the first result object
    result = results[0]  # Since it's a list, we get the first element

    # Access the classification probabilities and get the top prediction
    if result.probs is not None:
        predicted_class_id = result.probs.top1  # Get the class with the highest probability
        confidence = result.probs.top1conf.item()  # Get the confidence of the top prediction

        predicted_class_name = class_names[predicted_class_id]

        # Annotate the frame with the predicted class and confidence score
        label = f"{predicted_class_name}: {confidence:.2f}"
        cv2.putText(frame, label, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

    # Display the annotated frame with the prediction
    cv2.imshow('Real-Time Driver Detection', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 224x224 c5 0.57, c9 0.18, c0 0.10, c6 0.10, c7 0.04, 27.9ms
# Speed: 11.0ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.41, c9 0.40, c6 0.11, c0 0.05, c7 0.02, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.50, c5 0.32, c6 0.08, c0 0.07, c7 0.02, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.47, c9 0.36, c0 0.10, c6 0.04, c7 0.03, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.47, c9 0.36, c0 0.10, c6 0.04, c7 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.46, c5 0.37, c6 0.09, c0 0.04, c7 0.03, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.46, c5 0.37, c6 0.09, c0 0.04, c7 0.03, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.41, c9 0.36, c0 0.11, c6 0.08, c7 0.03, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.41, c9 0.36, c0 0.11, c6 0.08, c7 0.03, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.45, c5 0.35, c6 0.11, c0 0.06, c7 0.02, 16.9ms
# Speed: 3.0ms preprocess, 16.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.45, c5 0.35, c6 0.11, c0 0.06, c7 0.02, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.46, c9 0.43, c6 0.05, c0 0.03, c7 0.01, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.46, c9 0.43, c6 0.05, c0 0.03, c7 0.01, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.54, c5 0.33, c6 0.06, c7 0.03, c0 0.02, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.54, c5 0.33, c6 0.06, c7 0.03, c0 0.02, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.64, c5 0.26, c6 0.05, c0 0.04, c7 0.01, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.64, c5 0.26, c6 0.05, c0 0.04, c7 0.01, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.43, c9 0.42, c6 0.07, c0 0.05, c7 0.03, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.43, c9 0.42, c6 0.07, c0 0.05, c7 0.03, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.55, c9 0.37, c6 0.05, c0 0.02, c7 0.01, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.55, c9 0.37, c6 0.05, c0 0.02, c7 0.01, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.56, c9 0.34, c6 0.05, c0 0.03, c7 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.56, c9 0.34, c6 0.05, c0 0.03, c7 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.58,
 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.43, c6 0.30, c5 0.14, c9 0.05, c7 0.03, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.43, c6 0.30, c5 0.14, c9 0.05, c7 0.03, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.41, c0 0.24, c5 0.19, c4 0.06, c7 0.06, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.41, c0 0.24, c5 0.19, c4 0.06, c7 0.06, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.32, c5 0.30, c6 0.14, c7 0.12, c9 0.06, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.32, c5 0.30, c6 0.14, c7 0.12, c9 0.06, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.61, c0 0.14, c7 0.09, c6 0.07, c2 0.05, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.61, c0 0.14, c7 0.09, c6 0.07, c2 0.05, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.46, c6 0.18, c7 0.11, c0 0.10, c2 0.07, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.46, c6 0.18, c7 0.11, c0 0.10, c2 0.07, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.32, c5 0.26, c0 0.19, c7 0.10, c2 0.05, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.32, c5 0.26, c0 0.19, c7 0.10, c2 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.43, c0 0.21, c5 0.14, c4 0.07, c8 0.05, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.43, c0 0.21, c5 0.14, c4 0.07, c8 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.68, c0 0.10, c4 0.07, c5 0.05, c9 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.68, c0 0.10, c4 0.07, c5 0.05, c9 0.03, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.39, c5 0.27, c4 0.15, c0 0.10, c8 0.03, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.39, c5 0.27, c4 0.15, c0 0.10, c8 0.03, 21.9ms
# Speed: 29.9ms preprocess, 21.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.56, c5 0.19, c0 0.09, c4 0.07, c8 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.56, c5 0.19, c0 0.09, c4 0.07, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.50, c5 0.26, c0 0.09, c4 0.06, c9 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.50, c5 0.26, c0 0.09, c4 0.06, c9 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.67, c5 0.12, c4 0.06, c8 0.04, c7 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.67, c5 0.12, c4 0.06, c8 0.04, c7 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.50, c5 0.15, c0 0.11, c4 0.11, c8 0.04, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.50, c5 0.15, c0 0.11, c4 0.11, c8 0.04, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.71, c5 0.11, c0 0.08, c4 0.03, c8 0.03, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.71, c5 0.11, c0 0.08, c4 0.03, c8 0.03, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c5 0.10, c0 0.09, c4 0.09, c8 0.05, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c5 0.10, c0 0.09, c4 0.09, c8 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.62, c5 0.11, c0 0.10, c4 0.06, c7 0.04, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.62, c5 0.11, c0 0.10, c4 0.06, c7 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.62, c4 0.14, c5 0.09, c0 0.06, c8 0.04, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.62, c4 0.14, c5 0.09, c0 0.06, c8 0.04, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c5 0.17, c4 0.08, c0 0.08, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c5 0.17, c4 0.08, c0 0.08, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.45, c5 0.17, c4 0.15, c0 0.15, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.45, c5 0.17, c4 0.15, c0 0.15, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c5 0.10, c0 0.10, c4 0.05, c7 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c5 0.10, c0 0.10, c4 0.05, c7 0.03, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.74, c5 0.08, c0 0.07, c4 0.04, c8 0.03, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.74, c5 0.08, c0 0.07, c4 0.04, c8 0.03, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c5 0.09, c4 0.09, c0 0.07, c8 0.06, 19.0ms
# Speed: 3.0ms preprocess, 19.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c5 0.09, c4 0.09, c0 0.07, c8 0.06, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c0 0.19, c5 0.14, c4 0.13, c8 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c0 0.19, c5 0.14, c4 0.13, c8 0.05, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c5 0.21, c4 0.16, c0 0.13, c8 0.04, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c5 0.21, c4 0.16, c0 0.13, c8 0.04, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.49, c5 0.17, c0 0.14, c4 0.10, c8 0.04, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.49, c5 0.17, c0 0.14, c4 0.10, c8 0.04, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.51, c5 0.15, c0 0.12, c4 0.11, c7 0.04, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.51, c5 0.15, c0 0.12, c4 0.11, c7 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.44, c5 0.23, c4 0.17, c0 0.08, c7 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.44, c5 0.23, c4 0.17, c0 0.08, c7 0.03, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.33, c4 0.23, c5 0.19, c0 0.12, c7 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0
 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c9 0.18, c5 0.17, c0 0.13, c4 0.05, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.38, c6 0.23, c9 0.21, c0 0.10, c4 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.38, c6 0.23, c9 0.21, c0 0.10, c4 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.33, c6 0.29, c5 0.21, c0 0.09, c4 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c9 0.33, c6 0.29, c5 0.21, c0 0.09, c4 0.04, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.29, c5 0.23, c0 0.19, c9 0.18, c4 0.05, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.29, c5 0.23, c0 0.19, c9 0.18, c4 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.37, c9 0.23, c5 0.17, c0 0.15, c4 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.37, c9 0.23, c5 0.17, c0 0.15, c4 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c5 0.21, c9 0.19, c0 0.11, c4 0.04, 21.9ms
# Speed: 21.9ms preprocess, 21.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c5 0.21, c9 0.19, c0 0.11, c4 0.04, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.35, c6 0.30, c9 0.14, c0 0.12, c4 0.04, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.35, c6 0.30, c9 0.14, c0 0.12, c4 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.30, c9 0.29, c5 0.20, c0 0.10, c4 0.09, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.30, c9 0.29, c5 0.20, c0 0.10, c4 0.09, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.47, c9 0.20, c5 0.11, c4 0.10, c0 0.09, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.47, c9 0.20, c5 0.11, c4 0.10, c0 0.09, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.55, c9 0.15, c5 0.14, c4 0.10, c0 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.55, c9 0.15, c5 0.14, c4 0.10, c0 0.04, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.82, c4 0.08, c9 0.04, c0 0.04, c5 0.01, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.82, c4 0.08, c9 0.04, c0 0.04, c5 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.84, c4 0.07, c9 0.05, c2 0.02, c0 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.84, c4 0.07, c9 0.05, c2 0.02, c0 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.76, c4 0.13, c9 0.04, c0 0.04, c2 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.76, c4 0.13, c9 0.04, c0 0.04, c2 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.64, c0 0.10, c4 0.10, c9 0.08, c2 0.04, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.64, c0 0.10, c4 0.10, c9 0.08, c2 0.04, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.49, c9 0.21, c0 0.15, c4 0.08, c5 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.49, c9 0.21, c0 0.15, c4 0.08, c5 0.03, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c4 0.08, c0 0.04, c9 0.04, c2 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c4 0.08, c0 0.04, c9 0.04, c2 0.02, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.86, c0 0.04, c4 0.03, c9 0.03, c2 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.86, c0 0.04, c4 0.03, c9 0.03, c2 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c0 0.07, c4 0.04, c9 0.03, c2 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c0 0.07, c4 0.04, c9 0.03, c2 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.86, c4 0.06, c0 0.04, c9 0.02, c2 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.86, c4 0.06, c0 0.04, c9 0.02, c2 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c4 0.07, c0 0.05, c2 0.03, c9 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c4 0.07, c0 0.05, c2 0.03, c9 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.88, c4 0.04, c0 0.03, c2 0.02, c9 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.88, c4 0.04, c0 0.03, c2 0.02, c9 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.75, c4 0.10, c0 0.08, c9 0.03, c2 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.75, c4 0.10, c0 0.08, c9 0.03, c2 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.77, c0 0.09, c4 0.04, c2 0.04, c9 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.77, c0 0.09, c4 0.04, c2 0.04, c9 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.80, c0 0.07, c4 0.05, c9 0.03, c2 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.80, c0 0.07, c4 0.05, c9 0.03, c2 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.75, c0 0.16, c4 0.03, c9 0.02, c2 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.75, c0 0.16, c4 0.03, c9 0.02, c2 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c0 0.09, c4 0.04, c9 0.02, c5 0.02, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c0 0.09, c4 0.04, c9 0.02, c5 0.02, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.51, c0 0.38, c9 0.04, c4 0.02, c5 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.51, c0 0.38, c9 0.04, c4 0.02, c5 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.75, c0 0.14, c9 0.03, c2 0.03, c4 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.75, c0 0.14, c9 0.03, c2 0.03, c4 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.83, c4 0.06, c0 0.05, c9 0.03, c2 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.83, c4 0.06, c0 0.05, c9 0.03, c2 0.01, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.65, c0 0.19, c4 0.08, c5 0.03, c9 0.03, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.65, c0 0.19, c4 0.08, c5 0.03, c9 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c0 0.14, c4 0.11, c9 0.04, c5 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c0 0.14, c4 0.11, c9 0.04, c5 0.02, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c0 0.19, c4 0.06, c9 0.03, c2 0.03, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.66, c0 0.19, c4 0.06, c9 0.03, c2 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.71, c0 0.14, c4 0.04, c9 0.04, c2 0.04, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.71, c0 0.14, c4 0.04, c9 0.04, c2 0.04, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.73, c0 0.09, c4 0.08, c9 0.06, c2 0.03, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.73, c0 0.09, c4 0.08, c9 0.06, c2 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c0 0.17, c4 0.08, c9 0.07, c2 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c0 0.17, c4 0.08, c9 0.07, c2 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.68, c0 0.13, c4 0.09, c9 0.05, c5 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.68, c0 0.13, c4 0.09, c9 0.05, c5 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.82, c0 0.05, c4 0.05, c9 0.04, c5 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.82, c0 0.05, c4 0.05, c9 0.04, c5 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.90, c2 0.03, c0 0.03, c9 0.02, c4 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.90, c2 0.03, c0 0.03, c9 0.02, c4 0.01, 13.9ms
# Speed: 2.0ms preprocess, 13.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c0 0.06, c9 0.05, c5 0.04, c4 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.81, c0 0.06, c9 0.05, c5 0.04, c4 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.74, c0 0.08, c5 0.07, c2 0.05, c9 0.03, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.74, c0 0.08, c5 0.07, c2 0.05, c9 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.82, c2 0.06, c0 0.05, c4 0.03, c5 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.82, c2 0.06, c0 0.05, c4 0.03, c5 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.59, c5 0.14, c0 0.13, c4 0.07, c2 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.59, c5 0.14, c0 0.13, c4 0.07, c2 0.05, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c0 0.16, c5 0.08, c4 0.07, c2 0.03, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c0 0.16, c5 0.08, c4 0.07, c2 0.03, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.73, c2 0.09, c0 0.06, c4 0.05, c5 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.73, c2 0.09, c0 0.06, c4 0.05, c5 0.03, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.78, c4 0.10, c0 0.05, c2 0.03, c5 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.78, c4 0.10, c0 0.05, c2 0.03, c5 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.59, c0 0.15, c2 0.08, c5 0.08, c4 0.06, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.59, c0 0.15, c2 0.08, c5 0.08, c4 0.06, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.58, c0 0.15, c4 0.08, c5 0.08, c2 0.07, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.58, c0 0.15, c4 0.08, c5 0.08, c2 0.07, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.58, c2 0.15, c0 0.10, c4 0.09, c5 0.05, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.58, c2 0.15, c0 0.10, c4 0.09, c5 0.05, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.57, c2 0.24, c0 0.08, c5 0.04, c4 0.04, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.57, c2 0.24, c0 0.08, c5 0.04, c4 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.67, c2 0.18, c4 0.05, c5 0.04, c0 0.04, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.67, c2 0.18, c4 0.05, c5 0.04, c0 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c2 0.31, c0 0.11, c5 0.06, c4 0.05, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c2 0.31, c0 0.11, c5 0.06, c4 0.05, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.68, c2 0.13, c4 0.08, c0 0.06, c5 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.68, c2 0.13, c4 0.08, c0 0.06, c5 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c2 0.15, c0 0.10, c4 0.07, c5 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.61, c2 0.15, c0 0.10, c4 0.07, c5 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.40, c2 0.26, c5 0.13, c0 0.09, c4 0.08, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.40, c2 0.26, c5 0.13, c0 0.09, c4 0.08, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.60, c4 0.14, c2 0.08, c0 0.07, c5 0.06, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# ...
#
# 0: 224x224 c5 0.48, c8 0.14, c2 0.11, c6 0.11, c1 0.05, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.32, c8 0.20, c6 0.12, c9 0.10, c2 0.06, 20.9ms
# Speed: 24.9ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.32, c8 0.20, c6 0.12, c9 0.10, c2 0.06, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.49, c5 0.21, c7 0.13, c9 0.06, c0 0.04, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.49, c5 0.21, c7 0.13, c9 0.06, c0 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.75, c7 0.06, c9 0.06, c5 0.06, c6 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.75, c7 0.06, c9 0.06, c5 0.06, c6 0.02, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.69, c5 0.12, c7 0.06, c9 0.04, c6 0.03, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.69, c5 0.12, c7 0.06, c9 0.04, c6 0.03, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.80, c5 0.06, c7 0.05, c6 0.03, c9 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.80, c5 0.06, c7 0.05, c6 0.03, c9 0.02, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.70, c9 0.08, c7 0.07, c5 0.07, c1 0.02, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.70, c9 0.08, c7 0.07, c5 0.07, c1 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.77, c5 0.07, c9 0.06, c7 0.04, c0 0.02, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.77, c5 0.07, c9 0.06, c7 0.04, c0 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.75, c7 0.07, c9 0.06, c5 0.05, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.75, c7 0.07, c9 0.06, c5 0.05, c6 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.78, c5 0.06, c9 0.05, c7 0.04, c6 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.78, c5 0.06, c9 0.05, c7 0.04, c6 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.87, c9 0.04, c5 0.03, c6 0.02, c7 0.01, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.87, c9 0.04, c5 0.03, c6 0.02, c7 0.01, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.88, c9 0.04, c5 0.03, c6 0.02, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.88, c9 0.04, c5 0.03, c6 0.02, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.87, c5 0.04, c9 0.03, c7 0.02, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.87, c5 0.04, c9 0.03, c7 0.02, c6 0.02, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.82, c5 0.05, c9 0.04, c7 0.04, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.82, c5 0.05, c9 0.04, c7 0.04, c6 0.02, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.91, c5 0.03, c9 0.03, c6 0.02, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.91, c5 0.03, c9 0.03, c6 0.02, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.83, c9 0.06, c5 0.04, c7 0.02, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.83, c9 0.06, c5 0.04, c7 0.02, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.87, c5 0.05, c9 0.02, c6 0.02, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.87, c5 0.05, c9 0.02, c6 0.02, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.88, c5 0.03, c9 0.03, c7 0.02, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.88, c5 0.03, c9 0.03, c7 0.02, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.84, c5 0.07, c9 0.04, c6 0.02, c7 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.84, c5 0.07, c9 0.04, c6 0.02, c7 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.84, c7 0.04, c9 0.03, c5 0.03, c6 0.03, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.84, c7 0.04, c9 0.03, c5 0.03, c6 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.82, c5 0.06, c9 0.04, c6 0.02, c7 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.82, c5 0.06, c9 0.04, c6 0.02, c7 0.02, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.94, c5 0.02, c9 0.01, c6 0.01, c7 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.94, c5 0.02, c9 0.01, c6 0.01, c7 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.82, c9 0.06, c5 0.05, c6 0.03, c7 0.01, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.82, c9 0.06, c5 0.05, c6 0.03, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.86, c9 0.05, c6 0.03, c5 0.03, c0 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.86, c9 0.05, c6 0.03, c5 0.03, c0 0.01, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.86, c5 0.05, c9 0.04, c6 0.02, c7 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.86, c5 0.05, c9 0.04, c6 0.02, c7 0.01, 10.0ms
# Speed: 2.0ms preprocess, 10.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.92, c5 0.03, c9 0.02, c6 0.01, c7 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.92, c5 0.03, c9 0.02, c6 0.01, c7 0.01, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.85, c9 0.07, c5 0.04, c6 0.01, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.85, c9 0.07, c5 0.04, c6 0.01, c7 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.80, c9 0.10, c5 0.04, c7 0.02, c6 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.80, c9 0.10, c5 0.04, c7 0.02, c6 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.88, c5 0.04, c9 0.04, c6 0.01, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.88, c5 0.04, c9 0.04, c6 0.01, c7 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.46, c9 0.22, c5 0.11, c6 0.08, c0 0.05, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.46, c9 0.22, c5 0.11, c6 0.08, c0 0.05, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.63, c6 0.11, c9 0.08, c5 0.08, c7 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.63, c6 0.11, c9 0.08, c5 0.08, c7 0.03, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.62, c6 0.11, c5 0.07, c0 0.06, c9 0.05, 11.0ms
# Speed: 3.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.62, c6 0.11, c5 0.07, c0 0.06, c9 0.05, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.41, c5 0.15, c0 0.13, c7 0.07, c4 0.06, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.41, c5 0.15, c0 0.13, c7 0.07, c4 0.06, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.56, c0 0.20, c5 0.07, c2 0.04, c4 0.04, 12.0ms
# Speed: 4.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.56, c0 0.20, c5 0.07, c2 0.04, c4 0.04, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.36, c5 0.32, c6 0.19, c2 0.04, c1 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.36, c5 0.32, c6 0.19, c2 0.04, c1 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.36, c0 0.29, c6 0.20, c2 0.05, c8 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.36, c0 0.29, c6 0.20, c2 0.05, c8 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.44, c0 0.30, c6 0.18, c2 0.03, c9 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.44, c0 0.30, c6 0.18, c2 0.03, c9 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.53, c0 0.33, c6 0.07, c2 0.03, c1 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.53, c0 0.33, c6 0.07, c2 0.03, c1 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.52, c0 0.38, c6 0.06, c2 0.01, c1 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.52, c0 0.38, c6 0.06, c2 0.01, c1 0.01, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.52, c0 0.36, c6 0.05, c2 0.02, c9 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.52, c0 0.36, c6 0.05, c2 0.02, c9 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.59, c0 0.32, c6 0.05, c2 0.02, c9 0.01, 17.0ms
# Speed: 2.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.59, c0 0.32, c6 0.05, c2 0.02, c9 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.54, c0 0.36, c6 0.06, c9 0.01, c2 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.54, c0 0.36, c6 0.06, c9 0.01, c2 0.01, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.49, c5 0.42, c6 0.05, c2 0.01, c9 0.01, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.49, c5 0.42, c6 0.05, c2 0.01, c9 0.01, 19.9ms
# Speed: 2.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.59, c5 0.35, c6 0.04, c2 0.01, c3 0.01, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.59, c5 0.35, c6 0.04, c2 0.01, c3 0.01, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.59, c5 0.36, c6 0.03, c3 0.01, c2 0.01, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.59, c5 0.36, c6 0.03, c3 0.01, c2 0.01, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.54, c5 0.42, c6 0.02, c2 0.01, c1 0.00, 11.0ms
# Speed: 2.0ms preprocess, 11.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.54, c5 0.42, c6 0.02, c2 0.01, c1 0.00, 12.0ms
# Speed: 5.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.61, c5 0.32, c6 0.04, c2 0.01, c3 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.61, c5 0.32, c6 0.04, c2 0.01, c3 0.01, 13.0ms
# Speed: 3.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.67, c0 0.27, c6 0.03, c2 0.01, c3 0.00, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.67, c0 0.27, c6 0.03, c2 0.01, c3 0.00, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.64, c0 0.25, c6 0.07, c9 0.01, c1 0.01, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.64, c0 0.25, c6 0.07, c9 0.01, c1 0.01, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.84, c0 0.12, c6 0.02, c2 0.01, c9 0.01, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.84, c0 0.12, c6 0.02, c2 0.01, c9 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)

# %% [markdown]
# ## <div style="background-color:#015958;font-family:sans-serif;color:#FFF9ED;font-size:150%;text-align:center;border-radius:9px 9px; padding: 15px; border-style: solid; border-color: black"> Real Time & Alert System</div>

# %%
import cv2
import winsound  # For sound alerts (Windows only)
from ultralytics import YOLO

# Load the pre-trained YOLOv8 classification model
model = YOLO(r"D:\Personal\5. Courses\Depi\Technical\Runs\Classify\Train\weights\best.pt")  # Replace with your custom trained model

# Capture video from the dashboard camera (or default camera)
cap = cv2.VideoCapture(0)  # '0' is for the default camera, adjust if necessary

# Set the frame width and height if necessary (optional)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 640)

# Define the class names based on your dataset (adjust as needed for your custom model)
class_names = [
    "safe driving", "texting - right", "talking on the phone - right",
    "texting - left", "talking on the phone - left", "operating the radio",
    "drinking", "reaching behind", "hair and makeup", "talking to passenger"
]

while True:
    # Read a frame from the camera
    ret, frame = cap.read()
    if not ret:
        print("Failed to capture video")
        break

    # Preprocess: Resize the frame to match YOLOv8 input size for classification
    input_frame = cv2.resize(frame, (224, 224))  # Resize to the input size required by your model

    # YOLOv8 classification inference on the frame (get predictions)
    results = model(input_frame)

    # YOLOv8 returns a list of results, so access the first result object
    result = results[0]  # Since it's a list, we get the first element

    # Access the classification probabilities and get the top prediction
    if result.probs is not None:
        predicted_class_id = result.probs.top1  # Get the class with the highest probability
        confidence = result.probs.top1conf.item()  # Get the confidence of the top prediction

        predicted_class_name = class_names[predicted_class_id]

        # Annotate the frame with the predicted class and confidence score
        label = f"{predicted_class_name}: {confidence:.2f}"
        cv2.putText(frame, label, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 2)

        # Trigger alert if the driver is not safe driving (c0)
        if predicted_class_id != 0:  # Any class except "safe driving" (c0)
            cv2.putText(frame, "ALERT!", (20, 100), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (0, 0, 255), 3)  # Display alert text
            cv2.rectangle(frame, (0, 0), (640, 640), (0, 0, 255), 10)  # Add a red border around the frame

            # Trigger a sound alert (Beep sound in Windows)
            winsound.Beep(1000, 500)  # Beep at 1000 Hz for 500 ms

    # Display the annotated frame with the prediction and alerts
    cv2.imshow('Real-Time Driver Detection', frame)

    # Break the loop if 'q' is pressed
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# Release the camera and close windows
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 224x224 c5 0.65, c0 0.17, c6 0.09, c2 0.06, c9 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.68, c5 0.23, c6 0.05, c2 0.02, c9 0.00, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.45, c5 0.40, c6 0.08, c2 0.04, c9 0.01, 19.9ms
# Speed: 4.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.45, c5 0.40, c6 0.08, c2 0.04, c9 0.01, 17.9ms
# Speed: 3.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.64, c5 0.29, c6 0.03, c2 0.02, c9 0.00, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.64, c5 0.29, c6 0.03, c2 0.02, c9 0.00, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.58, c5 0.33, c6 0.04, c2 0.02, c9 0.01, 18.9ms
# Speed: 2.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.58, c5 0.33, c6 0.04, c2 0.02, c9 0.01, 18.9ms
# Speed: 4.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.47, c0 0.37, c6 0.08, c2 0.04, c9 0.01, 16.0ms
# Speed: 3.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.60, c5 0.32, c6 0.05, c2 0.01, c1 0.00, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.60, c5 0.32, c6 0.05, c2 0.01, c1 0.00, 19.9ms
# Speed: 4.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.53, c5 0.36, c6 0.06, c2 0.02, c1 0.01, 17.0ms
# Speed: 4.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.57, c0 0.28, c6 0.07, c2 0.04, c1 0.01, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.50, c0 0.36, c6 0.07, c2 0.03, c9 0.01, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.62, c0 0.20, c2 0.09, c6 0.07, c9 0.01, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.55, c0 0.30, c2 0.07, c6 0.06, c9 0.01, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.64, c5 0.27, c6 0.05, c2 0.03, c8 0.00, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.64, c5 0.27, c6 0.05, c2 0.03, c8 0.00, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.70, c5 0.20, c6 0.04, c2 0.03, c9 0.01, 19.9ms
# Speed: 3.0ms preprocess, 19.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.70, c5 0.20, c6 0.04, c2 0.03, c9 0.01, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.63, c5 0.29, c6 0.04, c2 0.03, c9 0.01, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.63, c5 0.29, c6 0.04, c2 0.03, c9 0.01, 17.0ms
# Speed: 3.0ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.64, c0 0.20, c6 0.06, c2 0.06, c9 0.01, 15.0ms
# Speed: 4.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.53, c5 0.31, c6 0.09, c2 0.03, c1 0.01, 24.9ms
# Speed: 4.0ms preprocess, 24.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.53, c5 0.31, c6 0.09, c2 0.03, c1 0.01, 19.0ms
# Speed: 4.0ms preprocess, 19.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.45, c0 0.42, c6 0.07, c2 0.03, c1 0.01, 20.9ms
# Speed: 3.0ms preprocess, 20.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.47, c0 0.32, c6 0.13, c2 0.05, c1 0.01, 25.9ms
# Speed: 4.0ms preprocess, 25.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.57, c0 0.34, c6 0.07, c2 0.01, c1 0.01, 25.9ms
# Speed: 6.0ms preprocess, 25.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.58, c0 0.28, c6 0.05, c2 0.04, c9 0.01, 17.9ms
# Speed: 2.0ms preprocess, 17.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.39, c0 0.36, c6 0.15, c2 0.03, c1 0.03, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.56, c0 0.23, c6 0.10, c2 0.03, c1 0.03, 18.9ms
# Speed: 3.0ms preprocess, 18.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.24, c6 0.18, c2 0.17, c5 0.17, c8 0.16, 17.0ms
# Speed: 2.1ms preprocess, 17.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.42, c5 0.16, c8 0.13, c2 0.10, c4 0.09, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.24, c5 0.20, c2 0.19, c6 0.13, c9 0.07, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.50, c6 0.25, c0 0.09, c2 0.05, c9 0.05, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.74, c9 0.12, c2 0.08, c6 0.02, c0 0.02, 18.0ms
# Speed: 2.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.70, c8 0.14, c2 0.08, c6 0.03, c9 0.03, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.40, c6 0.29, c0 0.11, c2 0.05, c1 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.32, c5 0.18, c0 0.16, c7 0.10, c8 0.06, 29.4ms
# Speed: 4.0ms preprocess, 29.4ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.73, c6 0.07, c5 0.06, c7 0.04, c2 0.04, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.71, c6 0.12, c2 0.05, c5 0.04, c7 0.03, 16.5ms
# Speed: 2.0ms preprocess, 16.5ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.61, c6 0.17, c2 0.10, c5 0.06, c0 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c8 0.45, c6 0.21, c2 0.15, c0 0.06, c5 0.05, 35.9ms
# Speed: 9.0ms preprocess, 35.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.45, c0 0.35, c6 0.09, c2 0.05, c9 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.53, c6 0.19, c0 0.17, c2 0.08, c9 0.01, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.62, c0 0.24, c6 0.09, c8 0.02, c2 0.02, 18.0ms
# Speed: 3.0ms preprocess, 18.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.48, c0 0.37, c2 0.07, c6 0.04, c9 0.01, 30.9ms
# Speed: 6.0ms preprocess, 30.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.65, c0 0.17, c6 0.06, c8 0.05, c2 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.69, c0 0.13, c8 0.06, c6 0.05, c2 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.62, c0 0.16, c6 0.07, c8 0.06, c2 0.04, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c5 0.64, c0 0.17, c6 0.09, c7 0.02, c2 0.02, 27.9ms
# Speed: 4.0ms preprocess, 27.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.40, c2 0.35, c5 0.13, c0 0.07, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.44, c6 0.18, c5 0.16, c2 0.14, c1 0.02, 23.9ms
# Speed: 5.0ms preprocess, 23.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.36, c2 0.22, c6 0.20, c5 0.11, c8 0.03, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.33, c6 0.25, c2 0.22, c5 0.12, c1 0.02, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.33, c6 0.25, c2 0.22, c5 0.12, c1 0.02, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.30, c2 0.25, c6 0.20, c5 0.14, c8 0.04, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.30, c2 0.25, c6 0.20, c5 0.14, c8 0.04, 12.0ms
# Speed: 2.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c2 0.30, c0 0.29, c6 0.18, c5 0.15, c8 0.03, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.29, c6 0.28, c2 0.22, c5 0.11, c8 0.05, 14.0ms
# Speed: 5.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.29, c6 0.28, c2 0.22, c5 0.11, c8 0.05, 14.0ms
# Speed: 3.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.35, c6 0.27, c2 0.17, c5 0.11, c8 0.03, 15.0ms
# Speed: 3.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.35, c6 0.27, c2 0.17, c5 0.11, c8 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c2 0.34, c6 0.24, c0 0.20, c5 0.13, c8 0.05, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.31, c2 0.26, c0 0.24, c5 0.12, c8 0.03, 15.0ms
# Speed: 1.0ms preprocess, 15.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.41, c6 0.24, c2 0.19, c5 0.08, c8 0.03, 15.0ms
# Speed: 2.0ms preprocess, 15.0ms inference, 1.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.41, c6 0.24, c2 0.19, c5 0.08, c8 0.03, 16.0ms
# Speed: 6.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.49, c6 0.27, c2 0.12, c5 0.08, c8 0.02, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.49, c6 0.27, c2 0.12, c5 0.08, c8 0.02, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.35, c6 0.34, c2 0.16, c5 0.10, c8 0.03, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c0 0.35, c6 0.34, c2 0.16, c5 0.10, c8 0.03, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.33, c0 0.29, c2 0.22, c5 0.09, c8 0.04, 12.0ms
# Speed: 3.0ms preprocess, 12.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
#
# 0: 224x224 c6 0.57, c0 0.20, c2 0.09, c5 0.08, c8 0.02, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
